# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool = sns.load_dataset('iris')
phool
#draw a bar plot
sns.barplot(x='species', y='sepal_width', data=phool)
plt.show()

# %%
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool = sns.load_dataset('iris')
phool
#draw a bar plot
sns.barplot(x='species', y='petal_length', data=phool)
plt.show()

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='who', y='alone', hue='sex', data=kashti)
plt.show()

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='sex', y='alone', hue='who', data=kashti)
plt.show()

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'])
plt.show()

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='red')
plt.show()

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='blue')
plt.show()

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='yellow')
plt.show()

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='blue', ci = None)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5444\107889382.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='blue', ci = None)

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='blue', ci = None, palette='pastel')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5444\1984205529.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='blue', ci = None, palette='pastel')

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='blue', ci = None, palette='colorblind')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5444\266496501.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='blue', ci = None, palette='colorblind')

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='blue', ci = None, palette='dark')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5444\3468428270.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='sex', y='alone', hue='who', data=kashti, order=['female', 'male'], color='blue', ci = None, palette='dark')

# %%
#import libraries
import seaborn as sns
from numpy import mean
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='class', y='fare', hue='sex', data=kashti, estimator=mean)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
#import libraries
import seaborn as sns
from numpy import median 
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='class', y='fare', hue='sex', data=kashti, estimator=median)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
#import libraries
import seaborn as sns
from numpy import mean
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='class', y='fare', hue='sex', data=kashti, estimator=mean, saturation=0.1)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
#horizontal plot
#import libraries
import seaborn as sns
from numpy import mean
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset('titanic')
kashti
#draw a bar plot
sns.barplot(x='fare', y='class', hue='sex', data=kashti, estimator=mean, saturation=1)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# read a titanic.csv file
# from seaborn library
kashti = sns.load_dataset('titanic')

sns.barplot(x='class', y='fare', data=kashti,
            linewidth=2.5, facecolor=(0.2, 0.2, 0.2, 0),
            errcolor='1', edgecolor='0.2')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='class', ylabel='fare'>
